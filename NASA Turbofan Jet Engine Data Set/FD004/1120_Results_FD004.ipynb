# %% [markdown]
# # **Import**

# %%
import warnings

warnings.filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # **Data Load**

# %%
cd /content/drive/MyDrive/[Projects]/Kaggle/NASA 터보팬 제트 엔진의 잔존 수명 예측 및 예지보전 방안/Results_FD004
# Out:
# /content/drive/MyDrive/[Projects]/Kaggle/NASA 터보팬 제트 엔진의 잔존 수명 예측 및 예지보전 방안/Results_FD004

# %%
lr_result = pd.read_csv('./Linear_Regression.csv')
rr_result = pd.read_csv('./Regularized_Regression.csv')
bg_result = pd.read_csv('./Bagging_Regression.csv')
bo_result = pd.read_csv('./Boosting_Regression.csv')
sq_result = pd.read_csv('./Sequence_Regression.csv')

# %% [markdown]
# # **Result**

# %% [markdown]
# ## **Linear Regression**

# %%
lr_result = lr_result.sort_values(by='MAE').head()

# %%
lr_result.reset_index(drop=True).drop(columns='Unnamed: 0')
# Out:
#                              Data   Model          Scaler        MAE  \
# 0  Cumulative Stat (RUL Clipping)  Linear             NaN  17.630382
# 1  Cumulative Stat (RUL Clipping)  Linear    RobustScaler  17.630382
# 2  Cumulative Stat (RUL Clipping)  Linear  StandardScaler  17.630382
# 3  Cumulative Stat (RUL Clipping)  Linear    MinMaxScaler  17.630382
# 4              Raw (RUL Clipping)  Linear    RobustScaler  21.770973
#
#         RMSE
# 0  21.542402
# 1  21.542402
# 2  21.542402
# 3  21.542402
# 4  26.051968

# %%
g = sns.catplot(
    data=lr_result,
    x='Model',
    y='MAE',
    hue='Scaler',
    col='Data',
    kind='bar',
    height=5,
    aspect=1.2
)

g.fig.suptitle("Model Performance (MAE) by Scaler & Data", y=1.05)
plt.show()

# %% [markdown]
# ## **Regularized Regression**

# %%
rr_result = rr_result.sort_values(by='MAE').head()

# %%
rr_result.reset_index(drop=True).drop(columns='Unnamed: 0')
# Out:
#                              Data       Model          Scaler        MAE  \
# 0  Cumulative Stat (RUL Clipping)       Ridge    RobustScaler  17.715606
# 1  Cumulative Stat (RUL Clipping)       Ridge            None  17.742342
# 2  Cumulative Stat (RUL Clipping)       Ridge  StandardScaler  17.745798
# 3  Cumulative Stat (RUL Clipping)       Ridge    MinMaxScaler  18.219899
# 4  Cumulative Stat (RUL Clipping)  ElasticNet            None  21.773577
#
#         RMSE
# 0  21.641515
# 1  21.558355
# 2  21.696824
# 3  22.233853
# 4  26.210920

# %%
g = sns.catplot(
    data=rr_result,
    x='Model',
    y='MAE',
    hue='Scaler',
    col='Data',
    kind='bar',
    height=5,
    aspect=1.2
)

g.fig.suptitle("Model Performance (MAE) by Scaler & Data", y=1.05)
plt.show()

# %% [markdown]
# ## **Bagging Regression**

# %%
bg_result = bg_result.sort_values(by='MAE').head()

# %%
bg_result.reset_index(drop=True).drop(columns='Unnamed: 0')
# Out:
#                              Data         Model Scaler        MAE       RMSE
# 0  Cumulative Stat (RUL Clipping)  RandomForest   None  14.085685  20.226423
# 1  Cumulative Stat (RUL Clipping)       Bagging   None  14.515726  21.491899
# 2              Raw (RUL Clipping)       Bagging   None  14.537097  20.125730
# 3              Raw (RUL Clipping)  RandomForest   None  14.622258  19.808460
# 4                 Cumulative Stat  RandomForest   None  22.779234  31.577347

# %%
g = sns.catplot(
    data=bg_result,
    x='Model',
    y='MAE',
    hue='Scaler',
    col='Data',
    kind='bar',
    height=5,
    aspect=1.2
)

g.fig.suptitle("Model Performance (MAE) by Scaler & Data", y=1.05)
plt.show()

# %% [markdown]
# ## **Boosting Regression**

# %%
bo_result = bo_result.sort_values(by='MAE').head()

# %%
bo_result.reset_index(drop=True).drop(columns='Unnamed: 0')
# Out:
#                              Data     Model Scaler        MAE       RMSE
# 0  Cumulative Stat (RUL Clipping)  LightGBM   None  13.540428  18.731705
# 1  Cumulative Stat (RUL Clipping)  CatBoost   None  13.683681  18.547914
# 2  Cumulative Stat (RUL Clipping)   XGBoost   None  14.183904  19.826313
# 3              Raw (RUL Clipping)   XGBoost   None  14.307033  19.851915
# 4              Raw (RUL Clipping)  CatBoost   None  14.403875  19.742004

# %%
g = sns.catplot(
    data=bo_result,
    x='Model',
    y='MAE',
    hue='Scaler',
    col='Data',
    kind='bar',
    height=5,
    aspect=1.2
)

g.fig.suptitle("Model Performance (MAE) by Scaler & Data", y=1.05)
plt.show()

# %% [markdown]
# ## **Sequence Regression**

# %%
sq_result = sq_result.sort_values(by='MAE').head()

# %%
sq_result
# Out:
#                                    Data Model          Scaler        MAE  \
# 44              Raw (RUL Clipping) - 50  LSTM  StandardScaler  11.412210
# 42              Raw (RUL Clipping) - 50  LSTM    MinMaxScaler  12.116726
# 90  Cumulative Stat (RUL Clipping) - 50  LSTM    MinMaxScaler  12.252406
# 36              Raw (RUL Clipping) - 40  LSTM  StandardScaler  12.289542
# 38              Raw (RUL Clipping) - 40  LSTM    RobustScaler  12.512035
#
#          RMSE
# 44  16.287795
# 42  16.991025
# 90  17.543150
# 36  17.392301
# 38  17.375655

# %%
g = sns.catplot(
    data=sq_result,
    x='Model',
    y='MAE',
    hue='Scaler',
    col='Data',
    kind='bar',
    height=5,
    aspect=1.2
)

g.fig.suptitle("Model Performance (MAE) by Scaler & Data", y=1.05)
plt.show()

# %% [markdown]
# ## **All Result**

# %%
results = pd.concat([lr_result, rr_result, bg_result, bo_result, sq_result])
results = results.sort_values(by='MAE').head(10)

# %%
results.reset_index(drop=True).drop(columns='Unnamed: 0')
# Out:
#                                   Data         Model          Scaler  \
# 0              Raw (RUL Clipping) - 50          LSTM  StandardScaler
# 1              Raw (RUL Clipping) - 50          LSTM    MinMaxScaler
# 2  Cumulative Stat (RUL Clipping) - 50          LSTM    MinMaxScaler
# 3              Raw (RUL Clipping) - 40          LSTM  StandardScaler
# 4              Raw (RUL Clipping) - 40          LSTM    RobustScaler
# 5       Cumulative Stat (RUL Clipping)      LightGBM            None
# 6       Cumulative Stat (RUL Clipping)      CatBoost            None
# 7       Cumulative Stat (RUL Clipping)  RandomForest            None
# 8       Cumulative Stat (RUL Clipping)       XGBoost            None
# 9                   Raw (RUL Clipping)       XGBoost            None
#
#          MAE       RMSE
# 0  11.412210  16.287795
# 1  12.116726  16.991025
# 2  12.252406  17.543150
# 3  12.289542  17.392301
# 4  12.512035  17.375655
# 5  13.540428  18.731705
# 6  13.683681  18.547914
# ...

# %%
g = sns.catplot(
    data=results,
    x='Model',
    y='MAE',
    hue='Scaler',
    col='Data',
    kind='bar',
    height=5,
    aspect=1.2
)

g.fig.suptitle("Model Performance (MAE) by Scaler & Data", y=1.05)
plt.show()

# %% [markdown]
# ## **RMSE - MAE**

# %%
results['RMSE - MAE'] = results['RMSE'] - results['MAE']

# %%
results.reset_index(drop=True).drop(columns='Unnamed: 0')
# Out:
#                                   Data         Model          Scaler  \
# 0              Raw (RUL Clipping) - 50          LSTM  StandardScaler
# 1              Raw (RUL Clipping) - 50          LSTM    MinMaxScaler
# 2  Cumulative Stat (RUL Clipping) - 50          LSTM    MinMaxScaler
# 3              Raw (RUL Clipping) - 40          LSTM  StandardScaler
# 4              Raw (RUL Clipping) - 40          LSTM    RobustScaler
# 5       Cumulative Stat (RUL Clipping)      LightGBM            None
# 6       Cumulative Stat (RUL Clipping)      CatBoost            None
# 7       Cumulative Stat (RUL Clipping)  RandomForest            None
# 8       Cumulative Stat (RUL Clipping)       XGBoost            None
# 9                   Raw (RUL Clipping)       XGBoost            None
#
#          MAE       RMSE  RMSE - MAE
# 0  11.412210  16.287795    4.875586
# 1  12.116726  16.991025    4.874300
# 2  12.252406  17.543150    5.290744
# 3  12.289542  17.392301    5.102759
# ...
