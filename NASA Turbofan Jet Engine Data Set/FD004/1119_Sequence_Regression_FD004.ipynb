# %% [markdown]
# # **Import**

# %%
import warnings

warnings.filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np

from sklearn.preprocessing import MinMaxScaler, StandardScaler, RobustScaler

# !pip install keras-tcn
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tcn import TCN

from tensorflow.keras.callbacks import EarlyStopping

from sklearn.metrics import mean_absolute_error, mean_squared_error

# %% [markdown]
# # **Data Load**

# %%
cd /content/drive/MyDrive/[Projects]/Kaggle/NASA 터보팬 제트 엔진의 잔존 수명 예측 및 예지보전 방안/Data
# Out:
# /content/drive/MyDrive/[Projects]/Kaggle/NASA 터보팬 제트 엔진의 잔존 수명 예측 및 예지보전 방안/Data

# %%
index_names = ['unit_number', 'time_cycles']
setting_names = ['setting_1', 'setting_2', 'setting_3']
sensor_names = [f's_{i + 1}' for i in range(21)]
col_names = index_names + setting_names + sensor_names

train_df = pd.read_csv('./train_FD004.csv')

# %%
max_cycle = train_df.groupby('unit_number')['time_cycles'].max().reset_index()
max_cycle.columns = ['unit_number', 'max_cycle']

train_df = train_df.merge(max_cycle, on='unit_number', how='left')

train_df['RUL'] = train_df['max_cycle'] - train_df['time_cycles']

# %%
test_df = pd.read_csv('./test_FD004.csv')
rul_df = pd.read_csv('./RUL_FD004.csv')

# %%
results = []

using_sensors = [
    's_2', 's_3', 's_4', 's_7', 's_8', 's_9', 's_10', 's_11', 's_12',
    's_13', 's_14', 's_15', 's_17', 's_20', 's_21'
]

# %%
train_df['setting_1'] = train_df['setting_1'].round(1)
train_df['setting_2'] = train_df['setting_2'].round(1)
train_df['setting_group'] = train_df[['setting_1','setting_2','setting_3']].astype(str).agg('_'.join, axis=1)
train_df = pd.get_dummies(train_df, columns=['setting_group'])
train_df.head()
# Out:
#    Unnamed: 0  unit_number  time_cycles  setting_1  setting_2  setting_3  \
# 0           0            1            1       42.0        0.8      100.0
# 1           1            1            2       20.0        0.7      100.0
# 2           2            1            3       42.0        0.8      100.0
# 3           3            1            4       42.0        0.8      100.0
# 4           4            1            5       25.0        0.6       60.0
#
#       s_1     s_2      s_3      s_4  ...     s_21  max_cycle  RUL  \
# 0  445.00  549.68  1343.43  1112.93  ...   6.3670        321  320
# 1  491.19  606.07  1477.61  1237.50  ...  14.6552        321  319
# 2  445.00  548.95  1343.12  1117.05  ...   6.4213        321  318
# 3  445.00  548.70  1341.24  1118.03  ...   6.4176        321  317
# 4  462.54  536.10  1255.23  1033.59  ...   8.6754        321  316
#
#    setting_group_0.0_0.0_100.0  setting_group_10.0_0.2_100.0  \
# 0                        False                         False
# 1                        False                         False
# 2                        False                         False
# 3                        False                         False
# 4                        False                         False
#
#    setting_group_10.0_0.3_100.0  setting_group_20.0_0.7_100.0  \
# 0                         False                         False
# 1                         False                          True
# 2                         False                         False
# 3                         False                         False
# 4                         False                         False
#
#    setting_group_25.0_0.6_60.0  setting_group_35.0_0.8_100.0  \
# 0                        False                         False
# 1                        False                         False
# 2                        False                         False
# 3                        False                         False
# 4                         True                         False
#
#    setting_group_42.0_0.8_100.0
# 0                          True
# 1                         False
# 2                          True
# 3                          True
# 4                         False
#
# [5 rows x 36 columns]

# %%
setting_group = [col for col in train_df.columns if col.startswith('setting_group')]
setting_group
# Out:
# ['setting_group_0.0_0.0_100.0',
#  'setting_group_10.0_0.2_100.0',
#  'setting_group_10.0_0.3_100.0',
#  'setting_group_20.0_0.7_100.0',
#  'setting_group_25.0_0.6_60.0',
#  'setting_group_35.0_0.8_100.0',
#  'setting_group_42.0_0.8_100.0']

# %%
test_df['setting_1'] = test_df['setting_1'].round(1)
test_df['setting_2'] = test_df['setting_2'].round(1)
test_df['setting_group'] = test_df[['setting_1','setting_2','setting_3']].astype(str).agg('_'.join, axis=1)
test_df = pd.get_dummies(test_df, columns=['setting_group'])
test_df.head()
# Out:
#    Unnamed: 0  unit_number  time_cycles  setting_1  setting_2  setting_3  \
# 0           0            1            1       20.0        0.7      100.0
# 1           1            1            2       25.0        0.6       60.0
# 2           2            1            3       42.0        0.8      100.0
# 3           3            1            4       42.0        0.8      100.0
# 4           4            1            5       35.0        0.8      100.0
#
#       s_1     s_2      s_3      s_4  ...    s_19   s_20     s_21  \
# 0  491.19  606.67  1481.04  1227.81  ...  100.00  24.31  14.7007
# 1  462.54  536.22  1256.17  1031.48  ...   84.93  14.36   8.5748
# 2  445.00  549.23  1340.13  1105.88  ...  100.00  10.39   6.4365
# 3  445.00  549.19  1339.70  1107.26  ...  100.00  10.56   6.2367
# 4  449.44  555.10  1353.04  1117.80  ...  100.00  14.85   8.9326
#
#    setting_group_0.0_0.0_100.0  setting_group_10.0_0.2_100.0  \
# 0                        False                         False
# 1                        False                         False
# 2                        False                         False
# 3                        False                         False
# 4                        False                         False
#
#    setting_group_10.0_0.3_100.0  setting_group_20.0_0.7_100.0  \
# 0                         False                          True
# 1                         False                         False
# 2                         False                         False
# 3                         False                         False
# 4                         False                         False
#
#    setting_group_25.0_0.6_60.0  setting_group_35.0_0.8_100.0  \
# 0                        False                         False
# 1                         True                         False
# 2                        False                         False
# 3                        False                         False
# 4                        False                          True
#
#    setting_group_42.0_0.8_100.0
# 0                         False
# 1                         False
# 2                          True
# 3                          True
# 4                         False
#
# [5 rows x 34 columns]

# %% [markdown]
# ## **Raw Data**

# %%
sensor_setting_cols = using_sensors + setting_group

def make_train_sequence_data(df, seq_len):
    x, y = [], []

    for unit in df['unit_number'].unique():
        unit_df = df[df['unit_number'] == unit]
        sensor_values = unit_df[sensor_setting_cols].values
        rul_values = unit_df['RUL'].values

        for i in range(len(unit_df) - seq_len + 1):
            x.append(sensor_values[i:i + seq_len])
            y.append(rul_values[i + seq_len - 1])

    return np.array(x), np.array(y)

def make_test_sequence_data(df, seq_len):
    x = []
    unit_list = df['unit_number'].unique()

    for unit in unit_list:
        unit_df = df[df['unit_number'] == unit]
        values = unit_df[sensor_setting_cols].values

        if len(unit_df) >= seq_len:
            x.append(values[-seq_len:])
        else:
            pad = np.repeat(values[-1:], seq_len - len(unit_df), axis=0)
            x.append(np.vstack([pad, values]))

    return np.array(x)

# %%
def build_lstm(seq_len, n_features):
    return Sequential([
        LSTM(64, input_shape=(seq_len, n_features)),
        Dropout(0.2),
        Dense(32, activation='relu'),
        Dense(1)
    ])

def build_tcn(seq_len, n_features):
    return Sequential([
        TCN(64, input_shape=(seq_len, n_features)),
        Dropout(0.2),
        Dense(32, activation='relu'),
        Dense(1)
    ])

# %%
raw_results = []

scaler_dict = {
    'None': None,
    'MinMaxScaler': MinMaxScaler(),
    'StandardScaler': StandardScaler(),
    'RobustScaler': RobustScaler()
}

for seq_len in [30, 40, 50]:
    for scaler_name, scaler in scaler_dict.items():
        train_x_sensors = train_df[using_sensors].copy()
        train_x_settings = train_df[setting_group].copy()
        test_x_sensors = test_df[using_sensors].copy()
        test_x_settings = test_df[setting_group].copy()

        if scaler:
            scaler.fit(train_x_sensors)

            train_x_sensors = scaler.transform(train_x_sensors)
            test_x_sensors = scaler.transform(test_x_sensors)

        scaled_train_df = pd.DataFrame(
            np.concatenate([train_x_sensors, train_x_settings], axis=1),
            columns=sensor_setting_cols
        )
        scaled_train_df['unit_number'] = train_df['unit_number'].values
        scaled_train_df['RUL'] = train_df['RUL'].values

        scaled_test_df = pd.DataFrame(
            np.concatenate([test_x_sensors, test_x_settings], axis=1),
            columns=sensor_setting_cols
        )
        scaled_test_df['unit_number'] = test_df['unit_number'].values

        train_x, train_y = make_train_sequence_data(scaled_train_df, seq_len)
        test_x = make_test_sequence_data(scaled_test_df, seq_len)

        model_dict = {
            'LSTM': build_lstm(seq_len, len(sensor_setting_cols)),
            'TCN': build_tcn(seq_len, len(sensor_setting_cols))
        }
        es = EarlyStopping(
            monitor='val_loss',
            patience=5,
            restore_best_weights=True,
            verbose=1
        )
        for model_name, model in model_dict.items():
            model.compile(optimizer='adam', loss='mse', metrics=['mae'])
            model.fit(
                train_x, train_y,
                epochs=500, batch_size=32,
                validation_split=0.2,
                callbacks=[es],
                verbose=0
            )

            pred = model.predict(test_x).ravel()
            true = rul_df['RUL'].copy().values.ravel()

            mae = mean_absolute_error(true, pred)
            rmse = mean_squared_error(true, pred)**0.5

            print(f'Seq: {seq_len}, Model: {model_name}, Scaler: {scaler_name}, MAE: {mae}, RMSE: {rmse}')

            raw_results.append({
                'Data': f'Raw - {seq_len}',
                'Model': model_name,
                'Scaler': scaler_name,
                'MAE': mae,
                'RMSE': rmse
            })
results.extend(raw_results)
# Out:
# Epoch 8: early stopping
# Restoring model weights from the end of the best epoch: 3.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Seq: 30, Model: LSTM, Scaler: None, MAE: 52.426692962646484, RMSE: 62.401619836372234
# Epoch 22: early stopping
# Restoring model weights from the end of the best epoch: 17.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 168ms/step
# Seq: 30, Model: TCN, Scaler: None, MAE: 52.53707504272461, RMSE: 62.49919335416958
# Epoch 20: early stopping
# Restoring model weights from the end of the best epoch: 15.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Seq: 30, Model: LSTM, Scaler: MinMaxScaler, MAE: 32.20425033569336, RMSE: 40.16518170367293
# Epoch 7: early stopping
# Restoring model weights from the end of the best epoch: 2.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 168ms/step
# Seq: 30, Model: TCN, Scaler: MinMaxScaler, MAE: 34.374794006347656, RMSE: 42.878950198403736
# Epoch 9: early stopping
# Restoring model weights from the end of the best epoch: 4.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Seq: 30, Model: LSTM, Scaler: StandardScaler, MAE: 29.662996292114258, RMSE: 39.77531039957844
# Epoch 7: early stopping
# Restoring model weights from the end of the best epoch: 2.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 169ms/step
# Seq: 30, Model: TCN, Scaler: StandardScaler, MAE: 29.112836837768555, RMSE: 37.52250138718849
# Epoch 10: early stopping
# Restoring model weights from the end of the best epoch: 5.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Seq: 30, Model: LSTM, Scaler: RobustScaler, MAE: 26.296016693115234, RMSE: 35.02068306283445
# Epoch 13: early stopping
# Restoring model weights from the end of the best epoch: 8.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 170ms/step
# Seq: 30, Model: TCN, Scaler: RobustScaler, MAE: 28.137636184692383, RMSE: 36.437974040119705
# Epoch 10: early stopping
# Restoring model weights from the end of the best epoch: 5.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Seq: 40, Model: LSTM, Scaler: None, MAE: 51.06196594238281, RMSE: 60.62236020348123
# Epoch 10: early stopping
# Restoring model weights from the end of the best epoch: 5.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 193ms/step
# Seq: 40, Model: TCN, Scaler: None, MAE: 50.052764892578125, RMSE: 59.29907151728853
# Epoch 24: early stopping
# Restoring model weights from the end of the best epoch: 19.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Seq: 40, Model: LSTM, Scaler: MinMaxScaler, MAE: 27.11308479309082, RMSE: 34.70268354345507
# Epoch 7: early stopping
# Restoring model weights from the end of the best epoch: 2.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 184ms/step
# Seq: 40, Model: TCN, Scaler: MinMaxScaler, MAE: 30.952966690063477, RMSE: 39.515362420044944
# Epoch 10: early stopping
# Restoring model weights from the end of the best epoch: 5.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Seq: 40, Model: LSTM, Scaler: StandardScaler, MAE: 28.471281051635742, RMSE: 38.25451394167834
# Epoch 8: early stopping
# Restoring model weights from the end of the best epoch: 3.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 184ms/step
# Seq: 40, Model: TCN, Scaler: StandardScaler, MAE: 31.034948348999023, RMSE: 40.84051159933372
# Epoch 8: early stopping
# Restoring model weights from the end of the best epoch: 3.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Seq: 40, Model: LSTM, Scaler: RobustScaler, MAE: 24.7554931640625, RMSE: 33.188185977491486
# Epoch 8: early stopping
# Restoring model weights from the end of the best epoch: 3.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 191ms/step
# Seq: 40, Model: TCN, Scaler: RobustScaler, MAE: 32.54710006713867, RMSE: 40.09741707947424
# Epoch 10: early stopping
# Restoring model weights from the end of the best epoch: 5.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Seq: 50, Model: LSTM, Scaler: None, MAE: 49.62858963012695, RMSE: 58.77475168426384
# Epoch 12: early stopping
# Restoring model weights from the end of the best epoch: 7.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 189ms/step
# Seq: 50, Model: TCN, Scaler: None, MAE: 47.234397888183594, RMSE: 55.4428790900768
# Epoch 21: early stopping
# Restoring model weights from the end of the best epoch: 16.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Seq: 50, Model: LSTM, Scaler: MinMaxScaler, MAE: 25.45720863342285, RMSE: 33.198852666310245
# Epoch 7: early stopping
# Restoring model weights from the end of the best epoch: 2.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 180ms/step
# Seq: 50, Model: TCN, Scaler: MinMaxScaler, MAE: 36.43880081176758, RMSE: 45.03860919654797
# Epoch 11: early stopping
# Restoring model weights from the end of the best epoch: 6.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Seq: 50, Model: LSTM, Scaler: StandardScaler, MAE: 26.572498321533203, RMSE: 37.60626058199535
# Epoch 8: early stopping
# Restoring model weights from the end of the best epoch: 3.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 201ms/step
# Seq: 50, Model: TCN, Scaler: StandardScaler, MAE: 25.2799072265625, RMSE: 34.35202890148466
# Epoch 8: early stopping
# Restoring model weights from the end of the best epoch: 3.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Seq: 50, Model: LSTM, Scaler: RobustScaler, MAE: 24.14255142211914, RMSE: 33.119145635375126
# Epoch 12: early stopping
# Restoring model weights from the end of the best epoch: 7.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 184ms/step
# Seq: 50, Model: TCN, Scaler: RobustScaler, MAE: 33.73179244995117, RMSE: 43.77446999830852

# %%
pd.DataFrame(raw_results).sort_values(by='MAE')
# Out:
#         Data Model          Scaler        MAE       RMSE
# 22  Raw - 50  LSTM    RobustScaler  24.142551  33.119146
# 14  Raw - 40  LSTM    RobustScaler  24.755493  33.188186
# 21  Raw - 50   TCN  StandardScaler  25.279907  34.352029
# 18  Raw - 50  LSTM    MinMaxScaler  25.457209  33.198853
# 6   Raw - 30  LSTM    RobustScaler  26.296017  35.020683
# 20  Raw - 50  LSTM  StandardScaler  26.572498  37.606261
# 10  Raw - 40  LSTM    MinMaxScaler  27.113085  34.702684
# 7   Raw - 30   TCN    RobustScaler  28.137636  36.437974
# 12  Raw - 40  LSTM  StandardScaler  28.471281  38.254514
# 5   Raw - 30   TCN  StandardScaler  29.112837  37.522501
# 4   Raw - 30  LSTM  StandardScaler  29.662996  39.775310
# 11  Raw - 40   TCN    MinMaxScaler  30.952967  39.515362
# 13  Raw - 40   TCN  StandardScaler  31.034948  40.840512
# 2   Raw - 30  LSTM    MinMaxScaler  32.204250  40.165182
# 15  Raw - 40   TCN    RobustScaler  32.547100  40.097417
# 23  Raw - 50   TCN    RobustScaler  33.731792  43.774470
# 3   Raw - 30   TCN    MinMaxScaler  34.374794  42.878950
# 19  Raw - 50   TCN    MinMaxScaler  36.438801  45.038609
# 17  Raw - 50   TCN            None  47.234398  55.442879
# 16  Raw - 50  LSTM            None  49.628590  58.774752
# 9   Raw - 40   TCN            None  50.052765  59.299072
# 8   Raw - 40  LSTM            None  51.061966  60.622360
# 0   Raw - 30  LSTM            None  52.426693  62.401620
# 1   Raw - 30   TCN            None  52.537075  62.499193

# %%
raw_clipping_results = []

scaler_dict = {
    'None': None,
    'MinMaxScaler': MinMaxScaler(),
    'StandardScaler': StandardScaler(),
    'RobustScaler': RobustScaler()
}

for seq_len in [30, 40, 50]:
    for scaler_name, scaler in scaler_dict.items():
        train_x_sensors = train_df[using_sensors].copy()
        train_x_settings = train_df[setting_group].copy()
        test_x_sensors = test_df[using_sensors].copy()
        test_x_settings = test_df[setting_group].copy()

        if scaler:
            scaler.fit(train_x_sensors)

            train_x_sensors = scaler.transform(train_x_sensors)
            test_x_sensors = scaler.transform(test_x_sensors)

        scaled_train_df = pd.DataFrame(
            np.concatenate([train_x_sensors, train_x_settings], axis=1),
            columns=sensor_setting_cols
        )
        scaled_train_df['unit_number'] = train_df['unit_number'].values

        train_rul_df = train_df.copy()
        train_rul_df.loc[train_rul_df['RUL'] > 125, 'RUL'] = 125
        scaled_train_df['RUL'] = train_rul_df['RUL'].values

        scaled_test_df = pd.DataFrame(
            np.concatenate([test_x_sensors, test_x_settings], axis=1),
            columns=sensor_setting_cols
        )
        scaled_test_df['unit_number'] = test_df['unit_number'].values

        train_x, train_y = make_train_sequence_data(scaled_train_df, seq_len)
        test_x = make_test_sequence_data(scaled_test_df, seq_len)

        model_dict = {
            'LSTM': build_lstm(seq_len, len(sensor_setting_cols)),
            'TCN': build_tcn(seq_len, len(sensor_setting_cols))
        }
        es = EarlyStopping(
            monitor='val_loss',
            patience=5,
            restore_best_weights=True,
            verbose=1
        )
        for model_name, model in model_dict.items():
            model.compile(optimizer='adam', loss='mse', metrics=['mae'])
            model.fit(
                train_x, train_y,
                epochs=500, batch_size=32,
                validation_split=0.2,
                callbacks=[es],
                verbose=0
            )

            pred = model.predict(test_x).ravel()
            true = rul_df['RUL'].copy()
            true.loc[true > 125] = 125
            true = true.values.ravel()

            mae = mean_absolute_error(true, pred)
            rmse = mean_squared_error(true, pred)**0.5

            print(f'Seq: {seq_len}, Model: {model_name}, Scaler: {scaler_name}, MAE: {mae}, RMSE: {rmse}')

            raw_clipping_results.append({
                'Data': f'Raw (RUL Clipping) - {seq_len}',
                'Model': model_name,
                'Scaler': scaler_name,
                'MAE': mae,
                'RMSE': rmse
            })
results.extend(raw_clipping_results)
# Out:
# Epoch 7: early stopping
# Restoring model weights from the end of the best epoch: 2.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Seq: 30, Model: LSTM, Scaler: None, MAE: 37.79010772705078, RMSE: 44.08772272324661
# Epoch 8: early stopping
# Restoring model weights from the end of the best epoch: 3.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 169ms/step
# Seq: 30, Model: TCN, Scaler: None, MAE: 38.39555740356445, RMSE: 42.994547653507034
# Epoch 40: early stopping
# Restoring model weights from the end of the best epoch: 35.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Seq: 30, Model: LSTM, Scaler: MinMaxScaler, MAE: 12.947137832641602, RMSE: 17.967538172451885
# Epoch 11: early stopping
# Restoring model weights from the end of the best epoch: 6.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 167ms/step
# Seq: 30, Model: TCN, Scaler: MinMaxScaler, MAE: 20.387001037597656, RMSE: 24.50378264206429
# Epoch 16: early stopping
# Restoring model weights from the end of the best epoch: 11.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Seq: 30, Model: LSTM, Scaler: StandardScaler, MAE: 14.217325210571289, RMSE: 18.867740675120427
# Epoch 11: early stopping
# Restoring model weights from the end of the best epoch: 6.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 167ms/step
# Seq: 30, Model: TCN, Scaler: StandardScaler, MAE: 17.92131996154785, RMSE: 22.365000275088025
# Epoch 11: early stopping
# Restoring model weights from the end of the best epoch: 6.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Seq: 30, Model: LSTM, Scaler: RobustScaler, MAE: 15.01069450378418, RMSE: 19.890608123028976
# Epoch 9: early stopping
# Restoring model weights from the end of the best epoch: 4.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 167ms/step
# Seq: 30, Model: TCN, Scaler: RobustScaler, MAE: 20.407596588134766, RMSE: 24.970590611914098
# Epoch 6: early stopping
# Restoring model weights from the end of the best epoch: 1.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Seq: 40, Model: LSTM, Scaler: None, MAE: 37.78335952758789, RMSE: 43.77952826066725
# Epoch 7: early stopping
# Restoring model weights from the end of the best epoch: 2.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 185ms/step
# Seq: 40, Model: TCN, Scaler: None, MAE: 37.85553741455078, RMSE: 44.66199282964907
# Epoch 32: early stopping
# Restoring model weights from the end of the best epoch: 27.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Seq: 40, Model: LSTM, Scaler: MinMaxScaler, MAE: 13.122982025146484, RMSE: 17.295241143474627
# Epoch 13: early stopping
# Restoring model weights from the end of the best epoch: 8.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 183ms/step
# Seq: 40, Model: TCN, Scaler: MinMaxScaler, MAE: 18.651596069335938, RMSE: 22.86384819314585
# Epoch 16: early stopping
# Restoring model weights from the end of the best epoch: 11.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Seq: 40, Model: LSTM, Scaler: StandardScaler, MAE: 12.289542198181152, RMSE: 17.392300781232017
# Epoch 8: early stopping
# Restoring model weights from the end of the best epoch: 3.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 184ms/step
# Seq: 40, Model: TCN, Scaler: StandardScaler, MAE: 14.458370208740234, RMSE: 18.213253284760626
# Epoch 11: early stopping
# Restoring model weights from the end of the best epoch: 6.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Seq: 40, Model: LSTM, Scaler: RobustScaler, MAE: 12.512035369873047, RMSE: 17.375655127599686
# Epoch 11: early stopping
# Restoring model weights from the end of the best epoch: 6.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 184ms/step
# Seq: 40, Model: TCN, Scaler: RobustScaler, MAE: 19.953702926635742, RMSE: 23.921302195542548
# Epoch 17: early stopping
# Restoring model weights from the end of the best epoch: 12.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Seq: 50, Model: LSTM, Scaler: None, MAE: 37.85106658935547, RMSE: 43.490373620564014
# Epoch 13: early stopping
# Restoring model weights from the end of the best epoch: 8.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 182ms/step
# Seq: 50, Model: TCN, Scaler: None, MAE: 38.99903106689453, RMSE: 43.35623721754533
# Epoch 32: early stopping
# Restoring model weights from the end of the best epoch: 27.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Seq: 50, Model: LSTM, Scaler: MinMaxScaler, MAE: 12.11672592163086, RMSE: 16.991025463139724
# Epoch 9: early stopping
# Restoring model weights from the end of the best epoch: 4.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 186ms/step
# Seq: 50, Model: TCN, Scaler: MinMaxScaler, MAE: 16.417858123779297, RMSE: 20.994466870110234
# Epoch 19: early stopping
# Restoring model weights from the end of the best epoch: 14.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Seq: 50, Model: LSTM, Scaler: StandardScaler, MAE: 11.412209510803223, RMSE: 16.287795027127004
# Epoch 6: early stopping
# Restoring model weights from the end of the best epoch: 1.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 185ms/step
# Seq: 50, Model: TCN, Scaler: StandardScaler, MAE: 17.028926849365234, RMSE: 21.597193132921305
# Epoch 10: early stopping
# Restoring model weights from the end of the best epoch: 5.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Seq: 50, Model: LSTM, Scaler: RobustScaler, MAE: 12.829434394836426, RMSE: 17.42613281770998
# Epoch 20: early stopping
# Restoring model weights from the end of the best epoch: 15.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 182ms/step
# Seq: 50, Model: TCN, Scaler: RobustScaler, MAE: 19.677804946899414, RMSE: 24.86278751719123

# %%
pd.DataFrame(raw_clipping_results).sort_values(by='MAE')
# Out:
#                        Data Model          Scaler        MAE       RMSE
# 20  Raw (RUL Clipping) - 50  LSTM  StandardScaler  11.412210  16.287795
# 18  Raw (RUL Clipping) - 50  LSTM    MinMaxScaler  12.116726  16.991025
# 12  Raw (RUL Clipping) - 40  LSTM  StandardScaler  12.289542  17.392301
# 14  Raw (RUL Clipping) - 40  LSTM    RobustScaler  12.512035  17.375655
# 22  Raw (RUL Clipping) - 50  LSTM    RobustScaler  12.829434  17.426133
# 2   Raw (RUL Clipping) - 30  LSTM    MinMaxScaler  12.947138  17.967538
# 10  Raw (RUL Clipping) - 40  LSTM    MinMaxScaler  13.122982  17.295241
# 4   Raw (RUL Clipping) - 30  LSTM  StandardScaler  14.217325  18.867741
# 13  Raw (RUL Clipping) - 40   TCN  StandardScaler  14.458370  18.213253
# 6   Raw (RUL Clipping) - 30  LSTM    RobustScaler  15.010695  19.890608
# 19  Raw (RUL Clipping) - 50   TCN    MinMaxScaler  16.417858  20.994467
# 21  Raw (RUL Clipping) - 50   TCN  StandardScaler  17.028927  21.597193
# 5   Raw (RUL Clipping) - 30   TCN  StandardScaler  17.921320  22.365000
# 11  Raw (RUL Clipping) - 40   TCN    MinMaxScaler  18.651596  22.863848
# 23  Raw (RUL Clipping) - 50   TCN    RobustScaler  19.677805  24.862788
# 15  Raw (RUL Clipping) - 40   TCN    RobustScaler  19.953703  23.921302
# 3   Raw (RUL Clipping) - 30   TCN    MinMaxScaler  20.387001  24.503783
# 7   Raw (RUL Clipping) - 30   TCN    RobustScaler  20.407597  24.970591
# 8   Raw (RUL Clipping) - 40  LSTM            None  37.783360  43.779528
# 0   Raw (RUL Clipping) - 30  LSTM            None  37.790108  44.087723
# 16  Raw (RUL Clipping) - 50  LSTM            None  37.851067  43.490374
# 9   Raw (RUL Clipping) - 40   TCN            None  37.855537  44.661993
# 1   Raw (RUL Clipping) - 30   TCN            None  38.395557  42.994548
# 17  Raw (RUL Clipping) - 50   TCN            None  38.999031  43.356237

# %% [markdown]
# ## **Cumulative Stat**

# %%
cum_stat_train_df = pd.read_csv('./cum_stat_train_FD004.csv')
cum_stat_test_df = pd.read_csv('./cum_stat_test_FD004.csv')

# %%
stat_cols = [col for col in cum_stat_train_df.columns if col.startswith('s_')]

# %%
stat_setting_cols = stat_cols + setting_group

def make_cum_train_sequence_data(df, seq_len):
    x, y = [], []

    for unit in df['unit_number'].unique():
        unit_df = df[df['unit_number'] == unit]
        sensor_values = unit_df[stat_setting_cols].values
        rul_values = unit_df['RUL'].values

        for i in range(len(unit_df) - seq_len + 1):
            x.append(sensor_values[i:i + seq_len])
            y.append(rul_values[i + seq_len - 1])

    return np.array(x), np.array(y)

def make_cum_test_sequence_data(df, seq_len):
    x = []
    unit_list = df['unit_number'].unique()

    for unit in unit_list:
        unit_df = df[df['unit_number'] == unit]
        values = unit_df[stat_setting_cols].values

        if len(unit_df) >= seq_len:
            x.append(values[-seq_len:])
        else:
            pad = np.repeat(values[-1:], seq_len - len(unit_df), axis=0)
            x.append(np.vstack([pad, values]))

    return np.array(x)

# %%
cum_stat_results = []

scaler_dict = {
    'None': None,
    'MinMaxScaler': MinMaxScaler(),
    'StandardScaler': StandardScaler(),
    'RobustScaler': RobustScaler()
}

for seq_len in [30, 40, 50]:
    for scaler_name, scaler in scaler_dict.items():
        train_x_stats = cum_stat_train_df[stat_cols].copy()
        train_x_settings = cum_stat_train_df[setting_group].copy()
        test_x_stats = cum_stat_test_df[stat_cols].copy()
        test_x_settings = cum_stat_test_df[setting_group].copy()

        if scaler:
            scaler.fit(train_x_stats)

            train_x_stats = scaler.transform(train_x_stats)
            test_x_stats = scaler.transform(test_x_stats)

        scaled_train_df = pd.DataFrame(
            np.concatenate([train_x_stats, train_x_settings], axis=1),
            columns=stat_setting_cols
        )
        scaled_train_df['unit_number'] = cum_stat_train_df['unit_number'].values
        scaled_train_df['RUL'] = cum_stat_train_df['RUL'].values

        scaled_test_df = pd.DataFrame(
            np.concatenate([test_x_stats, test_x_settings], axis=1),
            columns=stat_setting_cols
        )
        scaled_test_df['unit_number'] = cum_stat_test_df['unit_number'].values

        train_x, train_y = make_cum_train_sequence_data(scaled_train_df, seq_len)
        test_x = make_cum_test_sequence_data(scaled_test_df, seq_len)

        model_dict = {
            'LSTM': build_lstm(seq_len, len(stat_setting_cols)),
            'TCN': build_tcn(seq_len, len(stat_setting_cols))
        }
        es = EarlyStopping(
            monitor='val_loss',
            patience=5,
            restore_best_weights=True,
            verbose=1
        )
        for model_name, model in model_dict.items():
            model.compile(optimizer='adam', loss='mse', metrics=['mae'])
            model.fit(
                train_x, train_y,
                epochs=500, batch_size=32,
                validation_split=0.2,
                callbacks=[es],
                verbose=0
            )

            pred = model.predict(test_x).ravel()
            true = rul_df['RUL'].copy().values.ravel()

            mae = mean_absolute_error(true, pred)
            rmse = mean_squared_error(true, pred)**0.5

            print(f'Seq: {seq_len}, Model: {model_name}, Scaler: {scaler_name}, MAE: {mae}, RMSE: {rmse}')

            cum_stat_results.append({
                'Data': f'Cumulative Stat - {seq_len}',
                'Model': model_name,
                'Scaler': scaler_name,
                'MAE': mae,
                'RMSE': rmse
            })
results.extend(cum_stat_results)
# Out:
# Epoch 7: early stopping
# Restoring model weights from the end of the best epoch: 2.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Seq: 30, Model: LSTM, Scaler: None, MAE: 46.45683288574219, RMSE: 54.53930142925031
# Epoch 7: early stopping
# Restoring model weights from the end of the best epoch: 2.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 166ms/step
# Seq: 30, Model: TCN, Scaler: None, MAE: 45.957359313964844, RMSE: 53.685492268192206
# Epoch 26: early stopping
# Restoring model weights from the end of the best epoch: 21.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Seq: 30, Model: LSTM, Scaler: MinMaxScaler, MAE: 24.86740493774414, RMSE: 31.476788400467612
# Epoch 10: early stopping
# Restoring model weights from the end of the best epoch: 5.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 167ms/step
# Seq: 30, Model: TCN, Scaler: MinMaxScaler, MAE: 26.1522274017334, RMSE: 34.281146735259235
# Epoch 15: early stopping
# Restoring model weights from the end of the best epoch: 10.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Seq: 30, Model: LSTM, Scaler: StandardScaler, MAE: 23.188920974731445, RMSE: 30.417611331292314
# Epoch 6: early stopping
# Restoring model weights from the end of the best epoch: 1.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 182ms/step
# Seq: 30, Model: TCN, Scaler: StandardScaler, MAE: 26.811559677124023, RMSE: 35.46021200926734
# Epoch 13: early stopping
# Restoring model weights from the end of the best epoch: 8.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Seq: 30, Model: LSTM, Scaler: RobustScaler, MAE: 24.135072708129883, RMSE: 31.40660564164309
# Epoch 8: early stopping
# Restoring model weights from the end of the best epoch: 3.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 174ms/step
# Seq: 30, Model: TCN, Scaler: RobustScaler, MAE: 26.74901580810547, RMSE: 35.73018838887765
# Epoch 9: early stopping
# Restoring model weights from the end of the best epoch: 4.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Seq: 40, Model: LSTM, Scaler: None, MAE: 46.47982406616211, RMSE: 54.52658020836031
# Epoch 23: early stopping
# Restoring model weights from the end of the best epoch: 18.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 189ms/step
# Seq: 40, Model: TCN, Scaler: None, MAE: 45.09257507324219, RMSE: 53.17232956020805
# Epoch 27: early stopping
# Restoring model weights from the end of the best epoch: 22.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Seq: 40, Model: LSTM, Scaler: MinMaxScaler, MAE: 21.142377853393555, RMSE: 28.21869160085319
# Epoch 11: early stopping
# Restoring model weights from the end of the best epoch: 6.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 196ms/step
# Seq: 40, Model: TCN, Scaler: MinMaxScaler, MAE: 25.41775131225586, RMSE: 35.256393826709825
# Epoch 11: early stopping
# Restoring model weights from the end of the best epoch: 6.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Seq: 40, Model: LSTM, Scaler: StandardScaler, MAE: 24.601070404052734, RMSE: 33.43107414891122
# Epoch 7: early stopping
# Restoring model weights from the end of the best epoch: 2.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 187ms/step
# Seq: 40, Model: TCN, Scaler: StandardScaler, MAE: 24.466371536254883, RMSE: 33.81162270696461
# Epoch 13: early stopping
# Restoring model weights from the end of the best epoch: 8.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Seq: 40, Model: LSTM, Scaler: RobustScaler, MAE: 25.333349227905273, RMSE: 32.8215036010359
# Epoch 8: early stopping
# Restoring model weights from the end of the best epoch: 3.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 186ms/step
# Seq: 40, Model: TCN, Scaler: RobustScaler, MAE: 28.57597541809082, RMSE: 38.16135401724744
# Epoch 8: early stopping
# Restoring model weights from the end of the best epoch: 3.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Seq: 50, Model: LSTM, Scaler: None, MAE: 46.5608024597168, RMSE: 54.57625292022621
# Epoch 9: early stopping
# Restoring model weights from the end of the best epoch: 4.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 190ms/step
# Seq: 50, Model: TCN, Scaler: None, MAE: 46.065826416015625, RMSE: 54.13600719844995
# Epoch 34: early stopping
# Restoring model weights from the end of the best epoch: 29.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Seq: 50, Model: LSTM, Scaler: MinMaxScaler, MAE: 21.046510696411133, RMSE: 29.67132063232788
# Epoch 9: early stopping
# Restoring model weights from the end of the best epoch: 4.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 189ms/step
# Seq: 50, Model: TCN, Scaler: MinMaxScaler, MAE: 25.10015106201172, RMSE: 34.221175713109275
# Epoch 12: early stopping
# Restoring model weights from the end of the best epoch: 7.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Seq: 50, Model: LSTM, Scaler: StandardScaler, MAE: 24.65216064453125, RMSE: 32.590128184438385
# Epoch 13: early stopping
# Restoring model weights from the end of the best epoch: 8.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 184ms/step
# Seq: 50, Model: TCN, Scaler: StandardScaler, MAE: 29.370214462280273, RMSE: 39.60960922021479
# Epoch 6: early stopping
# Restoring model weights from the end of the best epoch: 1.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Seq: 50, Model: LSTM, Scaler: RobustScaler, MAE: 26.244552612304688, RMSE: 35.31128316487522
# Epoch 8: early stopping
# Restoring model weights from the end of the best epoch: 3.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 195ms/step
# Seq: 50, Model: TCN, Scaler: RobustScaler, MAE: 27.420406341552734, RMSE: 36.840661978308695

# %%
pd.DataFrame(cum_stat_results).sort_values(by='MAE')
# Out:
#                     Data Model          Scaler        MAE       RMSE
# 18  Cumulative Stat - 50  LSTM    MinMaxScaler  21.046511  29.671321
# 10  Cumulative Stat - 40  LSTM    MinMaxScaler  21.142378  28.218692
# 4   Cumulative Stat - 30  LSTM  StandardScaler  23.188921  30.417611
# 6   Cumulative Stat - 30  LSTM    RobustScaler  24.135073  31.406606
# 13  Cumulative Stat - 40   TCN  StandardScaler  24.466372  33.811623
# 12  Cumulative Stat - 40  LSTM  StandardScaler  24.601070  33.431074
# 20  Cumulative Stat - 50  LSTM  StandardScaler  24.652161  32.590128
# 2   Cumulative Stat - 30  LSTM    MinMaxScaler  24.867405  31.476788
# 19  Cumulative Stat - 50   TCN    MinMaxScaler  25.100151  34.221176
# 14  Cumulative Stat - 40  LSTM    RobustScaler  25.333349  32.821504
# 11  Cumulative Stat - 40   TCN    MinMaxScaler  25.417751  35.256394
# 3   Cumulative Stat - 30   TCN    MinMaxScaler  26.152227  34.281147
# 22  Cumulative Stat - 50  LSTM    RobustScaler  26.244553  35.311283
# 7   Cumulative Stat - 30   TCN    RobustScaler  26.749016  35.730188
# 5   Cumulative Stat - 30   TCN  StandardScaler  26.811560  35.460212
# 23  Cumulative Stat - 50   TCN    RobustScaler  27.420406  36.840662
# 15  Cumulative Stat - 40   TCN    RobustScaler  28.575975  38.161354
# 21  Cumulative Stat - 50   TCN  StandardScaler  29.370214  39.609609
# 9   Cumulative Stat - 40   TCN            None  45.092575  53.172330
# 1   Cumulative Stat - 30   TCN            None  45.957359  53.685492
# 17  Cumulative Stat - 50   TCN            None  46.065826  54.136007
# 0   Cumulative Stat - 30  LSTM            None  46.456833  54.539301
# 8   Cumulative Stat - 40  LSTM            None  46.479824  54.526580
# 16  Cumulative Stat - 50  LSTM            None  46.560802  54.576253

# %%
cum_stat_rul_clipping_results = []

scaler_dict = {
    'None': None,
    'MinMaxScaler': MinMaxScaler(),
    'StandardScaler': StandardScaler(),
    'RobustScaler': RobustScaler()
}

for seq_len in [30, 40, 50]:
    for scaler_name, scaler in scaler_dict.items():
        train_x_stats = cum_stat_train_df[stat_cols].copy()
        train_x_settings = cum_stat_train_df[setting_group].copy()
        test_x_stats = cum_stat_test_df[stat_cols].copy()
        test_x_settings = cum_stat_test_df[setting_group].copy()

        if scaler:
            scaler.fit(train_x_stats)

            train_x_stats = scaler.transform(train_x_stats)
            test_x_stats = scaler.transform(test_x_stats)

        scaled_train_df = pd.DataFrame(
            np.concatenate([train_x_stats, train_x_settings], axis=1),
            columns=stat_setting_cols
        )
        scaled_train_df['unit_number'] = cum_stat_train_df['unit_number'].values

        train_rul_df = cum_stat_train_df.copy()
        train_rul_df.loc[train_rul_df['RUL'] > 125, 'RUL'] = 125
        scaled_train_df['RUL'] = train_rul_df['RUL'].values

        scaled_test_df = pd.DataFrame(
            np.concatenate([test_x_stats, test_x_settings], axis=1),
            columns=stat_setting_cols
        )
        scaled_test_df['unit_number'] = cum_stat_test_df['unit_number'].values

        train_x, train_y = make_cum_train_sequence_data(scaled_train_df, seq_len)
        test_x = make_cum_test_sequence_data(scaled_test_df, seq_len)

        model_dict = {
            'LSTM': build_lstm(seq_len, len(stat_setting_cols)),
            'TCN': build_tcn(seq_len, len(stat_setting_cols))
        }
        es = EarlyStopping(
            monitor='val_loss',
            patience=5,
            restore_best_weights=True,
            verbose=1
        )
        for model_name, model in model_dict.items():
            model.compile(optimizer='adam', loss='mse', metrics=['mae'])
            model.fit(
                train_x, train_y,
                epochs=500, batch_size=32,
                validation_split=0.2,
                callbacks=[es],
                verbose=0
            )

            pred = model.predict(test_x).ravel()
            true = rul_df['RUL'].copy()
            true.loc[true > 125] = 125
            true = true.values.ravel()

            mae = mean_absolute_error(true, pred)
            rmse = mean_squared_error(true, pred)**0.5

            print(f'Seq: {seq_len}, Model: {model_name}, Scaler: {scaler_name}, MAE: {mae}, RMSE: {rmse}')

            cum_stat_rul_clipping_results.append({
                'Data': f'Cumulative Stat (RUL Clipping) - {seq_len}',
                'Model': model_name,
                'Scaler': scaler_name,
                'MAE': mae,
                'RMSE': rmse
            })
results.extend(cum_stat_rul_clipping_results)
# Out:
# Epoch 6: early stopping
# Restoring model weights from the end of the best epoch: 1.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Seq: 30, Model: LSTM, Scaler: None, MAE: 37.765987396240234, RMSE: 44.05299376620873
# Epoch 10: early stopping
# Restoring model weights from the end of the best epoch: 5.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 178ms/step
# Seq: 30, Model: TCN, Scaler: None, MAE: 37.493385314941406, RMSE: 44.1600966455259
# Epoch 28: early stopping
# Restoring model weights from the end of the best epoch: 23.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Seq: 30, Model: LSTM, Scaler: MinMaxScaler, MAE: 15.654744148254395, RMSE: 20.239925185958647
# Epoch 8: early stopping
# Restoring model weights from the end of the best epoch: 3.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 172ms/step
# Seq: 30, Model: TCN, Scaler: MinMaxScaler, MAE: 17.05877113342285, RMSE: 22.02119326650714
# Epoch 13: early stopping
# Restoring model weights from the end of the best epoch: 8.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Seq: 30, Model: LSTM, Scaler: StandardScaler, MAE: 16.15123748779297, RMSE: 21.890458405192277
# Epoch 6: early stopping
# Restoring model weights from the end of the best epoch: 1.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 174ms/step
# Seq: 30, Model: TCN, Scaler: StandardScaler, MAE: 18.87899398803711, RMSE: 24.827298995070425
# Epoch 10: early stopping
# Restoring model weights from the end of the best epoch: 5.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Seq: 30, Model: LSTM, Scaler: RobustScaler, MAE: 14.478898048400879, RMSE: 19.854820515559393
# Epoch 8: early stopping
# Restoring model weights from the end of the best epoch: 3.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 171ms/step
# Seq: 30, Model: TCN, Scaler: RobustScaler, MAE: 20.045015335083008, RMSE: 26.864406751269538
# Epoch 8: early stopping
# Restoring model weights from the end of the best epoch: 3.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Seq: 40, Model: LSTM, Scaler: None, MAE: 37.78437805175781, RMSE: 43.76759132944432
# Epoch 12: early stopping
# Restoring model weights from the end of the best epoch: 7.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 191ms/step
# Seq: 40, Model: TCN, Scaler: None, MAE: 37.797054290771484, RMSE: 42.93725408181032
# Epoch 26: early stopping
# Restoring model weights from the end of the best epoch: 21.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Seq: 40, Model: LSTM, Scaler: MinMaxScaler, MAE: 14.852690696716309, RMSE: 19.201096280907294
# Epoch 10: early stopping
# Restoring model weights from the end of the best epoch: 5.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 195ms/step
# Seq: 40, Model: TCN, Scaler: MinMaxScaler, MAE: 17.48566436767578, RMSE: 22.274148587824854
# Epoch 8: early stopping
# Restoring model weights from the end of the best epoch: 3.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Seq: 40, Model: LSTM, Scaler: StandardScaler, MAE: 15.360207557678223, RMSE: 21.522654817892615
# Epoch 8: early stopping
# Restoring model weights from the end of the best epoch: 3.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 198ms/step
# Seq: 40, Model: TCN, Scaler: StandardScaler, MAE: 21.339933395385742, RMSE: 30.05205241730068
# Epoch 8: early stopping
# Restoring model weights from the end of the best epoch: 3.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Seq: 40, Model: LSTM, Scaler: RobustScaler, MAE: 16.574485778808594, RMSE: 22.04191203662851
# Epoch 7: early stopping
# Restoring model weights from the end of the best epoch: 2.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 188ms/step
# Seq: 40, Model: TCN, Scaler: RobustScaler, MAE: 27.61368179321289, RMSE: 46.16782183986483
# Epoch 8: early stopping
# Restoring model weights from the end of the best epoch: 3.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Seq: 50, Model: LSTM, Scaler: None, MAE: 37.871421813964844, RMSE: 43.42818863778888
# Epoch 9: early stopping
# Restoring model weights from the end of the best epoch: 4.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 191ms/step
# Seq: 50, Model: TCN, Scaler: None, MAE: 37.5091438293457, RMSE: 42.41138509807832
# Epoch 26: early stopping
# Restoring model weights from the end of the best epoch: 21.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Seq: 50, Model: LSTM, Scaler: MinMaxScaler, MAE: 12.252406120300293, RMSE: 17.543150101350545
# Epoch 7: early stopping
# Restoring model weights from the end of the best epoch: 2.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 197ms/step
# Seq: 50, Model: TCN, Scaler: MinMaxScaler, MAE: 17.52452850341797, RMSE: 22.543930908357158
# Epoch 7: early stopping
# Restoring model weights from the end of the best epoch: 2.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Seq: 50, Model: LSTM, Scaler: StandardScaler, MAE: 17.064956665039062, RMSE: 22.848805923481127
# Epoch 6: early stopping
# Restoring model weights from the end of the best epoch: 1.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 192ms/step
# Seq: 50, Model: TCN, Scaler: StandardScaler, MAE: 22.103559494018555, RMSE: 32.86831376576364
# Epoch 17: early stopping
# Restoring model weights from the end of the best epoch: 12.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Seq: 50, Model: LSTM, Scaler: RobustScaler, MAE: 16.874752044677734, RMSE: 22.631720287764114
# Epoch 6: early stopping
# Restoring model weights from the end of the best epoch: 1.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 189ms/step
# Seq: 50, Model: TCN, Scaler: RobustScaler, MAE: 29.90141487121582, RMSE: 46.72145947410702

# %%
pd.DataFrame(cum_stat_rul_clipping_results).sort_values(by='MAE')
# Out:
#                                    Data Model          Scaler        MAE  \
# 18  Cumulative Stat (RUL Clipping) - 50  LSTM    MinMaxScaler  12.252406
# 6   Cumulative Stat (RUL Clipping) - 30  LSTM    RobustScaler  14.478898
# 10  Cumulative Stat (RUL Clipping) - 40  LSTM    MinMaxScaler  14.852691
# 12  Cumulative Stat (RUL Clipping) - 40  LSTM  StandardScaler  15.360208
# 2   Cumulative Stat (RUL Clipping) - 30  LSTM    MinMaxScaler  15.654744
# 4   Cumulative Stat (RUL Clipping) - 30  LSTM  StandardScaler  16.151237
# 14  Cumulative Stat (RUL Clipping) - 40  LSTM    RobustScaler  16.574486
# 22  Cumulative Stat (RUL Clipping) - 50  LSTM    RobustScaler  16.874752
# 3   Cumulative Stat (RUL Clipping) - 30   TCN    MinMaxScaler  17.058771
# 20  Cumulative Stat (RUL Clipping) - 50  LSTM  StandardScaler  17.064957
# 11  Cumulative Stat (RUL Clipping) - 40   TCN    MinMaxScaler  17.485664
# 19  Cumulative Stat (RUL Clipping) - 50   TCN    MinMaxScaler  17.524529
# 5   Cumulative Stat (RUL Clipping) - 30   TCN  StandardScaler  18.878994
# 7   Cumulative Stat (RUL Clipping) - 30   TCN    RobustScaler  20.045015
# 13  Cumulative Stat (RUL Clipping) - 40   TCN  StandardScaler  21.339933
# 21  Cumulative Stat (RUL Clipping) - 50   TCN  StandardScaler  22.103559
# 15  Cumulative Stat (RUL Clipping) - 40   TCN    RobustScaler  27.613682
# 23  Cumulative Stat (RUL Clipping) - 50   TCN    RobustScaler  29.901415
# 1   Cumulative Stat (RUL Clipping) - 30   TCN            None  37.493385
# 17  Cumulative Stat (RUL Clipping) - 50   TCN            None  37.509144
# 0   Cumulative Stat (RUL Clipping) - 30  LSTM            None  37.765987
# 8   Cumulative Stat (RUL Clipping) - 40  LSTM            None  37.784378
# 9   Cumulative Stat (RUL Clipping) - 40   TCN            None  37.797054
# 16  Cumulative Stat (RUL Clipping) - 50  LSTM            None  37.871422
#
#          RMSE
# 18  17.543150
# 6   19.854821
# 10  19.201096
# 12  21.522655
# 2   20.239925
# 4   21.890458
# 14  22.041912
# 22  22.631720
# 3   22.021193
# 20  22.848806
# 11  22.274149
# 19  22.543931
# 5   24.827299
# 7   26.864407
# 13  30.052052
# 21  32.868314
# 15  46.167822
# 23  46.721459
# 1   44.160097
# 17  42.411385
# 0   44.052994
# 8   43.767591
# 9   42.937254
# 16  43.428189

# %% [markdown]
# # **Result**

# %%
result = pd.DataFrame(results)
result.to_csv('/content/drive/MyDrive/[Projects]/Kaggle/NASA 터보팬 제트 엔진의 잔존 수명 예측 및 예지보전 방안/Results_FD004/Sequence_Regression.csv', index=False)

# %%
result = result.sort_values(by='MAE')
result.head()
# Out:
#                                    Data Model          Scaler        MAE  \
# 44              Raw (RUL Clipping) - 50  LSTM  StandardScaler  11.412210
# 42              Raw (RUL Clipping) - 50  LSTM    MinMaxScaler  12.116726
# 90  Cumulative Stat (RUL Clipping) - 50  LSTM    MinMaxScaler  12.252406
# 36              Raw (RUL Clipping) - 40  LSTM  StandardScaler  12.289542
# 38              Raw (RUL Clipping) - 40  LSTM    RobustScaler  12.512035
#
#          RMSE
# 44  16.287795
# 42  16.991025
# 90  17.543150
# 36  17.392301
# 38  17.375655
